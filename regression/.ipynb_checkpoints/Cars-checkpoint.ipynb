# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge,Lasso,LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.inspection import permutation_importance
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import re

# %% [markdown]
# # Data loading and initial assessment

# %%
df = pd.read_csv("used_cars.csv")
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df.shape
# Out:
# (4009, 12)

# %%
df.dtypes
# Out:
# brand           object
# model           object
# model_year       int64
# milage          object
# fuel_type       object
# engine          object
# transmission    object
# ext_col         object
# int_col         object
# accident        object
# clean_title     object
# price           object
# dtype: object

# %%
df.isna().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %%
col = df.columns
col
# Out:
# Index(['brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
df.info(memory_usage=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
# brand           4009 non-null object
# model           4009 non-null object
# model_year      4009 non-null int64
# milage          4009 non-null object
# fuel_type       3839 non-null object
# engine          4009 non-null object
# transmission    4009 non-null object
# ext_col         4009 non-null object
# int_col         4009 non-null object
# accident        3896 non-null object
# clean_title     3413 non-null object
# price           4009 non-null object
# dtypes: int64(1), object(11)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data cleaning

# %%
for c in col:
    print(f"{c}: {df[c].nunique()} : {df[c].dtypes} : {df[c].isna().sum()}")
# Out:
# brand: 57 : object : 0
# model: 1898 : object : 0
# model_year: 34 : int64 : 0
# milage: 2818 : object : 0
# fuel_type: 7 : object : 170
# engine: 1146 : object : 0
# transmission: 62 : object : 0
# ext_col: 319 : object : 0
# int_col: 156 : object : 0
# accident: 2 : object : 113
# clean_title: 1 : object : 596
# price: 1569 : object : 0

# %%
df[['brand','model']].head(10)
# Out:
#       brand                            model
# 0      Ford  Utility Police Interceptor Base
# 1   Hyundai                     Palisade SEL
# 2     Lexus                    RX 350 RX 350
# 3  INFINITI                 Q50 Hybrid Sport
# 4      Audi        Q3 45 S line Premium Plus
# 5     Acura                         ILX 2.4L
# 6      Audi             S3 2.0T Premium Plus
# 7       BMW                           740 iL
# 8     Lexus                   RC 350 F Sport
# 9     Tesla          Model X Long Range Plus

# %%
df['brand'].value_counts().head(20)
# Out:
# Ford             386
# BMW              375
# Mercedes-Benz    315
# Chevrolet        292
# Porsche          201
# Audi             200
# Toyota           199
# Lexus            163
# Jeep             143
# Land             130
# Nissan           116
# Cadillac         107
# GMC               91
# RAM               91
# Dodge             90
# Tesla             87
# Kia               76
# Hyundai           72
# Acura             64
# Subaru            64
# Name: brand, dtype: int64

# %%
df['model'].value_counts().head(20)
# Out:
# M3 Base                  30
# F-150 XLT                24
# Corvette Base            22
# 1500 Laramie             18
# Camaro 2SS               17
# Model Y Long Range       17
# Wrangler Sport           17
# Mustang GT Premium       16
# 911 Carrera              16
# M4 Base                  15
# F-250 Lariat             14
# Explorer XLT             14
# 911 Carrera S            14
# F-150 Lariat             13
# M5 Base                  13
# E-Class E 350 4MATIC     13
# E-Class E 350            13
# Land Cruiser Base        12
# Macan S                  12
# R1S Adventure Package    12
# Name: model, dtype: int64

# %%
df = df.drop(columns=['model'])

# %%
df.shape
# Out:
# (4009, 11)

# %%
df['milage'].head(10)
# Out:
# 0     51,000 mi.
# 1     34,742 mi.
# 2     22,372 mi.
# 3     88,900 mi.
# 4      9,835 mi.
# 5    136,397 mi.
# 6     84,000 mi.
# 7    242,000 mi.
# 8     23,436 mi.
# 9     34,000 mi.
# Name: milage, dtype: object

# %%
df['milage'].isna().sum()
# Out:
# 0

# %%
df['milage'].sample(10)
# Out:
# 2879      5,040 mi.
# 3476     89,563 mi.
# 2057    116,000 mi.
# 2199     29,025 mi.
# 210     115,000 mi.
# 2779     61,000 mi.
# 2303     75,980 mi.
# 3225    225,000 mi.
# 1635     92,149 mi.
# 1977    193,827 mi.
# Name: milage, dtype: object

# %%
df['milage'] = df['milage'].astype(str)
df['milage'] = df['milage'].str.replace(",","",regex=False)
df['milage'] = df['milage'].str.replace("mi","",regex=False)
df['milage'] = df['milage'].str.replace(".","",regex=False)
df['milage'] = df['milage'].astype(float)
df['milage'].dtypes
# Out:
# dtype('float64')

# %%
df['fuel_type'].dtypes
# Out:
# dtype('O')

# %%
df['fuel_type'].unique()
# Out:
# array(['E85 Flex Fuel', 'Gasoline', 'Hybrid', nan, 'Diesel',
#        'Plug-In Hybrid', '–', 'not supported'], dtype=object)

# %%
df['fuel_type'] = df['fuel_type'].replace(["–","not supported"],"unknown")
df['fuel_type'] = df['fuel_type'].fillna("unknown")
df['fuel_type'].unique()
# Out:
# array(['E85 Flex Fuel', 'Gasoline', 'Hybrid', 'unknown', 'Diesel',
#        'Plug-In Hybrid'], dtype=object)

# %%
df['fuel_type'].isna().sum()
# Out:
# 0

# %%
df = df.drop(columns = ['int_col','ext_col','clean_title'])

# %%
df['accident'].nunique()
# Out:
# 2

# %%
df['accident'] = df['accident'].replace({'At least 1 accident or damage reported':'yes',
                                        'None reported':'no'})
df['accident'] = df['accident'].fillna('unknown')
df['accident'].unique()
# Out:
# array(['yes', 'no', 'unknown'], dtype=object)

# %%
df['price'].nunique()
# Out:
# 1569

# %%
df['price'].isna().sum()
# Out:
# 0

# %%
df['price'] = df['price'].astype(str)
df['price'] = df['price'].str.replace("$","",regex=False)
df['price'] = df['price'].str.replace(",","",regex=False)
df['price'] = df['price'].astype(float)
df['price'].unique()
df['price'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# # feature engineering

# %%
df['transmission'].nunique()
# Out:
# 62

# %%
df['transmission'].head(5)
# Out:
# 0          6-Speed A/T
# 1    8-Speed Automatic
# 2            Automatic
# 3          7-Speed A/T
# 4    8-Speed Automatic
# Name: transmission, dtype: object

# %%
df['transmission'].sample(5)
# Out:
# 3217                               A/T
# 2332                               A/T
# 598                        6-Speed A/T
# 216                           Variable
# 57      Transmission w/Dual Shift Mode
# Name: transmission, dtype: object

# %%
def simplify_transmission(x):
    x = str(x).lower()
    if 'a/t' in x or 'automatic' in x:
        return 'Automatic'
    elif 'm/t' in x or 'manual' in x:
        return 'Manual'
    elif 'cvt' in x:
        return 'CVT'
    elif 'dual' in x:
        return 'Dual_Shift'
    else:
        return 'Unknown'

# %%
df['transmission'] = df['transmission'].apply(simplify_transmission)
df['transmission'].value_counts()
# Out:
# Automatic     3148
# Dual_Shift     398
# Manual         372
# CVT             63
# Unknown         28
# Name: transmission, dtype: int64

# %%
df.columns
# Out:
# Index(['brand', 'model_year', 'milage', 'fuel_type', 'transmission',
#        'accident', 'price', 'HP', 'engine_size'],
#       dtype='object')

# %%
def HP_extractor(x):
    x = str(x)
    match = re.search(r'(\d+\.?\d*)HP',x)
    if match:
        return float(match.group(1))
    else:
        return np.nan

# %%
def engine_size_extractor(x):
    x = str(x)
    match = re.search(r'(\d+\.?\d*)L',x)
    if match:
        return float(match.group(1))
    else:
        return np.nan

# %%
def cylinder_extractor(x):
    x = str(x)
    match = re.search(r'V(\d+)|I(\d+)|(\d+)\sCylinder|Straight\s(\d+)',x)
    if match:
        for group in match.groups():
            if group:
                return int(group)
    
    return np.nan

# %%
def has_turbo(x):
    x = str(x).lower()
    if 'turbo' in x:
        return 1
    else:
        return 0

# %%
def is_electric(x):
    x = str(x).lower()
    if 'electric' in x:
        return 1
    else:
        return 0

# %%
df.columns
# Out:
# Index(['brand', 'model_year', 'milage', 'fuel_type', 'transmission',
#        'accident', 'price', 'HP', 'engine_size'],
#       dtype='object')

# %%
df['HP'] = df['engine'].apply(HP_extractor)
df['engine_size'] = df['engine'].apply(engine_size_extractor)
df['cylinder'] = df['engine'].apply(cylinder_extractor)
df['turbo'] = df['engine'].apply(has_turbo)
df['electric'] = df['engine'].apply(is_electric)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ds_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'engine'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4067/3585469557.py in <module>
# ...

# %%
df = df.drop(columns=['engine'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4067/2302999731.py in <module>
# ----> 1 df = df.drop(columns=['engine'])
#
# ~/miniconda3/envs/ds_env/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/miniconda3/envs/ds_env/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df.head()
# Out:
#       brand  model_year   milage      fuel_type transmission accident  \
# 0      Ford        2013  51000.0  E85 Flex Fuel    Automatic      yes
# 1   Hyundai        2021  34742.0       Gasoline    Automatic      yes
# 2     Lexus        2022  22372.0       Gasoline    Automatic       no
# 3  INFINITI        2015  88900.0         Hybrid    Automatic       no
# 4      Audi        2021   9835.0       Gasoline    Automatic       no
#
#      price     HP  engine_size  cylinder  turbo  electric
# 0  10300.0  300.0          3.7       6.0      0         0
# 1  38005.0    NaN          3.8       NaN      0         0
# 2  54598.0    NaN          NaN       NaN      0         0
# 3  15500.0  354.0          3.5       6.0      0         1
# 4  34999.0    NaN          2.0       NaN      1         0

# %%
df.isna().sum().tail()
# Out:
# HP             808
# engine_size    377
# cylinder       945
# turbo            0
# electric         0
# dtype: int64

# %%
df['HP'] = df['HP'].fillna(df['HP'].median())
df['engine_size'] = df['HP'].fillna(df['engine_size'].median())
df['cylinder'] = df['HP'].fillna(df['cylinder'].median())

df.isna().sum()
# Out:
# brand           0
# model_year      0
# milage          0
# fuel_type       0
# transmission    0
# accident        0
# price           0
# HP              0
# engine_size     0
# cylinder        0
# turbo           0
# electric        0
# dtype: int64

# %%
df['age'] = 2026-df['model_year']
df = df.drop(columns=['model_year'])
df.columns
# Out:
# Index(['brand', 'milage', 'fuel_type', 'transmission', 'accident', 'price',
#        'HP', 'engine_size', 'cylinder', 'turbo', 'electric', 'age'],
#       dtype='object')

# %% [markdown]
# # Exploratory data analysis

# %%
numeric = df._get_numeric_data()
numeric.head(20)
# Out:
#       milage     price     HP  engine_size  cylinder  turbo  electric  age
# 0    51000.0   10300.0  300.0        300.0     300.0      0         0   13
# 1    34742.0   38005.0  310.0        310.0     310.0      0         0    5
# 2    22372.0   54598.0  310.0        310.0     310.0      0         0    4
# 3    88900.0   15500.0  354.0        354.0     354.0      0         1   11
# 4     9835.0   34999.0  310.0        310.0     310.0      1         0    5
# 5   136397.0   14798.0  310.0        310.0     310.0      0         0   10
# 6    84000.0   31000.0  292.0        292.0     292.0      0         0    9
# 7   242000.0    7300.0  282.0        282.0     282.0      0         0   25
# 8    23436.0   41927.0  311.0        311.0     311.0      0         0    5
# 9    34000.0   69950.0  534.0        534.0     534.0      0         1    6
# 10   27608.0   73897.0  310.0        310.0     310.0      0         0    5
# ...

# %%
num_col = numeric.columns
for x in num_col:
    print(f"{x}: {numeric[x].skew()}")
# Out:
# milage: 1.1599748853042458
# price: 19.513551204216057
# HP: 1.1704809879688711
# engine_size: 1.1704809879688711
# cylinder: 1.1704809879688711
# turbo: 3.2398261954638357
# electric: 2.941861125925147
# age: 1.0892312577318568

# %%
numeric.hist(figsize=(12,8))
plt.show()

# %%
numeric.corr()['price']
# Out:
# milage        -0.305528
# price          1.000000
# HP             0.267426
# engine_size    0.267426
# cylinder       0.267426
# turbo          0.139124
# electric       0.028009
# age           -0.199496
# Name: price, dtype: float64

# %%
numeric.describe(include='all')
# Out:
#               milage         price           HP  engine_size     cylinder  \
# count    4009.000000  4.009000e+03  4009.000000  4009.000000  4009.000000
# mean    64717.551010  4.455319e+04   327.730856   327.730856   327.730856
# std     52296.599459  7.871064e+04   109.604837   109.604837   109.604837
# min       100.000000  2.000000e+03    70.000000    70.000000    70.000000
# 25%     23044.000000  1.720000e+04   268.000000   268.000000   268.000000
# 50%     52775.000000  3.100000e+04   310.000000   310.000000   310.000000
# 75%     94100.000000  4.999000e+04   381.000000   381.000000   381.000000
# max    405000.000000  2.954083e+06  1020.000000  1020.000000  1020.000000
#
#              turbo     electric          age
# count  4009.000000  4009.000000  4009.000000
# mean      0.074582     0.086555    10.484410
# std       0.262749     0.281217     6.104816
# min       0.000000     0.000000     2.000000
# 25%       0.000000     0.000000     6.000000
# ...

# %%
character = df.drop(columns=numeric.columns)
character = character.drop(columns=['transmission','ext_col','int_col','engine','model','model_year'])
character.head(2)
# Out:
#      brand      fuel_type accident clean_title
# 0     Ford  E85 Flex Fuel      yes         Yes
# 1  Hyundai       Gasoline      yes         Yes

# %%
cl_data = pd.concat([numeric,character],axis=1)
cl_data.head()
# Out:
#     milage    price   HP  eng_size  cylinder  age     brand      fuel_type  \
# 0  51000.0  10300.0  0.0       7.0       6.0   13      Ford  E85 Flex Fuel
# 1  34742.0  38005.0  0.0       8.0       6.0    5   Hyundai       Gasoline
# 2  22372.0  54598.0  0.0       4.0       6.0    4     Lexus       Gasoline
# 3  88900.0  15500.0  0.0       5.0       6.0   11  INFINITI         Hybrid
# 4   9835.0  34999.0  0.0       0.0       6.0    5      Audi       Gasoline
#
#   accident clean_title
# 0      yes         Yes
# 1      yes         Yes
# 2       no     unknown
# 3       no         Yes
# 4       no     unknown

# %% [markdown]
# # preprocessing

# %%
cl_data.shape
# Out:
# (4009, 10)

# %%
x = cl_data.drop(columns=['price'])
y = cl_data['price']
z = x.columns
print('price' in z)
# Out:
# False

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train = x_train.copy()
x_test = x_test.copy()

x_train['milage'] = np.log1p(x_train['milage'])
x_test['milage'] = np.log1p(x_test['milage'])

y_train = np.log1p(y_train)
y_test = np.log1p(y_test)

x_train.columns
# Out:
# Index(['milage', 'HP', 'eng_size', 'cylinder', 'age', 'brand', 'fuel_type',
#        'accident', 'clean_title'],
#       dtype='object')

# %%
x_train = pd.get_dummies(x_train,columns=['brand','fuel_type','accident','clean_title'])
x_test = pd.get_dummies(x_test,columns=['brand','fuel_type','accident','clean_title'])

x_train,x_test = x_train.align(x_test,join='outer',axis=1,fill_value=0)

# %%
sc = StandardScaler()
X_train_scaled = sc.fit_transform(x_train)
X_test_scaled = sc.transform(x_test)

# %% [markdown]
# # model training

# %%
model1 = LinearRegression()
model1.fit(X_train_scaled,y_train)
p_train = model1.predict(X_train_scaled)
p_test = model1.predict(X_test_scaled)

p_test_exp = np.expm1(p_test)
p_train_exp = np.expm1(p_train)
y_train = np.expm1(y_train)
y_test = np.expm1(y_test)

# %% [markdown]
# # model evaluation

# %%
r2_train = r2_score(y_train,p_train_exp)
r2_test = r2_score(y_test,p_test_exp)
rmse_train = np.sqrt(mean_squared_error(y_train,p_train_exp))
rmse_test = np.sqrt(mean_squared_error(y_test,p_test_exp))
print("r2 train:",r2_train)
print("r2 test:",r2_test)
print("rmse train:",rmse_train)
print("rmse test:",rmse_test)
# Out:
# r2 train: 0.6627858256296046
# r2 test: 0.02268199424153139
# rmse train: 29729.90049015707
# rmse test: 141336.33932708114

# %% [markdown]
# # ridge model

# %%
ridge_model = Ridge()
para_grid = {"alpha":[0.01,0.1,1,10,100]}
grid = GridSearchCV(
        estimator = ridge_model,
        param_grid = para_grid,
        cv = 5,
        scoring = "neg_mean_squared_error")

grid.fit(x_train,y_train)
print("best alpha:",grid.best_params_)
best_model = grid.best_estimator_
y_pred = best_model.predict(x_test)
print("mse:",mean_squared_error(y_test,y_pred))
print("r2 score on train:",best_model.score(x_train,y_train))
print("r2 score on train:",best_model.score(x_test,y_test))
# Out:
# best alpha: {'alpha': 0.1}
# mse: 0.236700823383518
# r2 score on train: 0.7718504124771829
# r2 score on train: 0.6960237560512967

# %%
ridge_model = Lasso()
para_grid = {"alpha":[0.01,0.1,1,10,100]}
grid = GridSearchCV(
        estimator = ridge_model,
        param_grid = para_grid,
        cv = 5,
        scoring = "neg_mean_squared_error")

grid.fit(x_train,y_train)
print("best alpha:",grid.best_params_)
best_model = grid.best_estimator_
y_pred = best_model.predict(x_test)
print("mse:",mean_squared_error(y_test,y_pred))
print("r2 score on train:",best_model.score(x_train,y_train))
print("r2 score on train:",best_model.score(x_test,y_test))
# Out:
# best alpha: {'alpha': 0.01}
# mse: 0.27964755901279176
# r2 score on train: 0.6902202318023756
# r2 score on train: 0.6408706425139925

# %% [markdown]
# # feature importance

# %%
result = permutation_importance(
model1,x_test,y_test,scoring='neg_mean_squared_error',random_state=42)
imp = pd.DataFrame({
'feature':x.columns,
'importance':result.importances_mean}).sort_values(by='importance',ascending=False)
print(imp.head(10))
# Out:
#               feature  importance
# 4                 age    0.280336
# 0              milage    0.192746
# 3            cylinder    0.077886
# 48      brand_Porsche    0.045143
# 30  brand_Lamborghini    0.026360
# 51  brand_Rolls-Royce    0.010076
# 10      brand_Bentley    0.008048
# 24      brand_Hyundai    0.007933
# 29          brand_Kia    0.006384
# 44       brand_Nissan    0.006181

# %% [markdown]
# # Tree models

# %%
model = DecisionTreeRegressor(random_state=42)
para_grid = {"max_depth":[3,5,10,None],
            "min_samples_split":[2,5,10],
            "min_samples_leaf":[1,2,5]}
grid = GridSearchCV(
        estimator = model,
        param_grid = para_grid,
        cv = 5,
        scoring = "neg_mean_squared_error")

grid.fit(x_train,y_train)
best_tree = grid.best_estimator_
y_pred_test_tree = best_tree.predict(x_test)
y_pred_train_tree = best_tree.predict(x_train)
#print("mse:",mean_squared_error(y_test,y_pred_t))
print("r2 score on test:",r2_score(y_test,y_pred_test_tree))
print("r2 score on train:",r2_score(y_train,y_pred_train_tree))
# Out:
# r2 score on test: 0.6875373917705941
# r2 score on train: 0.8412386693884087

# %% [markdown]
# # RandomForest regressor

# %%
random_model = RandomForestRegressor(random_state = 42)
para_grid = {"n_estimators":[50,100],
             "max_depth":[5,10],
            "min_samples_split":[2,5],
            "min_samples_leaf":[1,2]}

grid = GridSearchCV(
        estimator = random_model,
        param_grid = para_grid,
        cv = 3,
        scoring = "neg_mean_squared_error",
        n_jobs =-1)

grid.fit(x_train,y_train)
best_Rtree=grid.best_estimator_
y_pred_test_tree = best_Rtree.predict(x_test)
y_pred_train_tree = best_Rtree.predict(x_train)
print("r2 score on test:",r2_score(y_test,y_pred_test_tree))
print("r2 score on train:",r2_score(y_train,y_pred_train_tree))
# Out:
# r2 score on test: 0.7438524919709602
# r2 score on train: 0.8844873507197534
