# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Data loading and initial assessment

# %%
df = pd.read_csv("AmesHousing.csv")

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour    ...     Pool Area Pool QC  Fence  \
# 0   NaN       IR1          Lvl    ...             0     NaN    NaN
# 1   NaN       Reg          Lvl    ...             0     NaN  MnPrv
# 2   NaN       IR1          Lvl    ...             0     NaN    NaN
# 3   NaN       Reg          Lvl    ...             0     NaN    NaN
# 4   NaN       IR1          Lvl    ...             0     NaN  MnPrv
#
#   Misc Feature Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df.tail()
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour    ...     Pool Area Pool QC  Fence  \
# 2925   NaN       IR1          Lvl    ...             0     NaN  GdPrv
# 2926   NaN       IR1          Low    ...             0     NaN  MnPrv
# 2927   NaN       Reg          Lvl    ...             0     NaN  MnPrv
# 2928   NaN       Reg          Lvl    ...             0     NaN    NaN
# 2929   NaN       Reg          Lvl    ...             0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  \
# ...

# %%
df.info(memory_usage = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
# Order              2930 non-null int64
# PID                2930 non-null int64
# MS SubClass        2930 non-null int64
# MS Zoning          2930 non-null object
# Lot Frontage       2440 non-null float64
# Lot Area           2930 non-null int64
# Street             2930 non-null object
# Alley              198 non-null object
# Lot Shape          2930 non-null object
# Land Contour       2930 non-null object
# Utilities          2930 non-null object
# Lot Config         2930 non-null object
# Land Slope         2930 non-null object
# Neighborhood       2930 non-null object
# Condition 1        2930 non-null object
# Condition 2        2930 non-null object
# Bldg Type          2930 non-null object
# House Style        2930 non-null object
# Overall Qual       2930 non-null int64
# Overall Cond       2930 non-null int64
# Year Built         2930 non-null int64
# ...

# %%
df.columns.tolist()
# Out:
# ['Order',
#  'PID',
#  'MS SubClass',
#  'MS Zoning',
#  'Lot Frontage',
#  'Lot Area',
#  'Street',
#  'Alley',
#  'Lot Shape',
#  'Land Contour',
#  'Utilities',
#  'Lot Config',
#  'Land Slope',
#  'Neighborhood',
#  'Condition 1',
#  'Condition 2',
#  'Bldg Type',
#  'House Style',
#  'Overall Qual',
#  'Overall Cond',
#  'Year Built',
#  'Year Remod/Add',
#  'Roof Style',
#  'Roof Matl',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Exter Qual',
#  'Exter Cond',
#  'Foundation',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Heating',
#  'Heating QC',
#  'Central Air',
#  'Electrical',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Low Qual Fin SF',
#  'Gr Liv Area',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Full Bath',
#  'Half Bath',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'Kitchen Qual',
#  'TotRms AbvGrd',
# ...

# %% [markdown]
# # Data Cleaning

# %%
a = (df.isna().sum()/df.shape[0])*100
a
# Out:
# Order              0.000000
# PID                0.000000
# MS SubClass        0.000000
# MS Zoning          0.000000
# Lot Frontage      16.723549
# Lot Area           0.000000
# Street             0.000000
# Alley             93.242321
# Lot Shape          0.000000
# Land Contour       0.000000
# Utilities          0.000000
# Lot Config         0.000000
# Land Slope         0.000000
# Neighborhood       0.000000
# Condition 1        0.000000
# Condition 2        0.000000
# Bldg Type          0.000000
# House Style        0.000000
# Overall Qual       0.000000
# Overall Cond       0.000000
# Year Built         0.000000
# Year Remod/Add     0.000000
# Roof Style         0.000000
# Roof Matl          0.000000
# Exterior 1st       0.000000
# Exterior 2nd       0.000000
# Mas Vnr Type       0.784983
# Mas Vnr Area       0.784983
# Exter Qual         0.000000
# Exter Cond         0.000000
#                     ...
# Bedroom AbvGr      0.000000
# Kitchen AbvGr      0.000000
# ...

# %%
df.nunique()
# Out:
# Order             2930
# PID               2930
# MS SubClass         16
# MS Zoning            7
# Lot Frontage       128
# Lot Area          1960
# Street               2
# Alley                2
# Lot Shape            4
# Land Contour         4
# Utilities            3
# Lot Config           5
# Land Slope           3
# Neighborhood        28
# Condition 1          9
# Condition 2          8
# Bldg Type            5
# House Style          8
# Overall Qual        10
# Overall Cond         9
# Year Built         118
# Year Remod/Add      61
# Roof Style           6
# Roof Matl            8
# Exterior 1st        16
# Exterior 2nd        17
# Mas Vnr Type         5
# Mas Vnr Area       445
# Exter Qual           4
# Exter Cond           5
#                   ...
# Bedroom AbvGr        8
# Kitchen AbvGr        4
# Kitchen Qual         5
# TotRms AbvGrd       14
# Functional           8
# Fireplaces           5
# Fireplace Qu         5
# Garage Type          6
# Garage Yr Blt      103
# ...

# %%
b = df._get_numeric_data()
b = b.drop(columns=['PID','Order'])
b.head()
# Out:
#    MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0           20         141.0     31770             6             5
# 1           20          80.0     11622             5             6
# 2           20          81.0     14267             6             6
# 3           20          93.0     11160             7             5
# 4           60          74.0     13830             5             5
#
#    Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0        1960            1960         112.0         639.0           0.0
# 1        1961            1961           0.0         468.0         144.0
# 2        1958            1958         108.0         923.0           0.0
# 3        1968            1968           0.0        1065.0           0.0
# 4        1997            1998           0.0         791.0           0.0
#
#      ...      Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# ...

# %%
b.isna().sum()/b.shape[0]*100
# Out:
# MS SubClass         0.000000
# Lot Frontage       16.723549
# Lot Area            0.000000
# Overall Qual        0.000000
# Overall Cond        0.000000
# Year Built          0.000000
# Year Remod/Add      0.000000
# Mas Vnr Area        0.784983
# BsmtFin SF 1        0.034130
# BsmtFin SF 2        0.034130
# Bsmt Unf SF         0.034130
# Total Bsmt SF       0.034130
# 1st Flr SF          0.000000
# 2nd Flr SF          0.000000
# Low Qual Fin SF     0.000000
# Gr Liv Area         0.000000
# Bsmt Full Bath      0.068259
# Bsmt Half Bath      0.068259
# Full Bath           0.000000
# Half Bath           0.000000
# Bedroom AbvGr       0.000000
# Kitchen AbvGr       0.000000
# TotRms AbvGrd       0.000000
# Fireplaces          0.000000
# Garage Yr Blt       5.426621
# Garage Cars         0.034130
# Garage Area         0.034130
# Wood Deck SF        0.000000
# Open Porch SF       0.000000
# Enclosed Porch      0.000000
# 3Ssn Porch          0.000000
# Screen Porch        0.000000
# ...

# %%
b['Lot Frontage'] = b['Lot Frontage'].fillna(b['Lot Frontage'].median())
b['Year Remod/Add'] = b['Year Remod/Add'].fillna(b['Year Remod/Add'].median())
b['Mas Vnr Area'] = b['Mas Vnr Area'].fillna(b['Mas Vnr Area'].median())
b['BsmtFin SF 1'] = b['BsmtFin SF 1'].fillna(b['BsmtFin SF 1'].median())
b['BsmtFin SF 2'] = b['BsmtFin SF 2'].fillna(b['BsmtFin SF 2'].median())
b['Bsmt Unf SF'] = b['Bsmt Unf SF'].fillna(b['Bsmt Unf SF'].median())
b['Total Bsmt SF'] = b['Total Bsmt SF'].fillna(b['Total Bsmt SF'].median())
b['Garage Yr Blt'] = b['Garage Yr Blt'].fillna(b['Garage Yr Blt'].median())     
b['Garage Cars'] = b['Garage Cars'].fillna(b['Garage Cars'].mode()[0])       
b['Garage Area'] = b['Garage Area'].fillna(b['Garage Area'].median())    
b['Bsmt Full Bath'] = b['Bsmt Full Bath'].fillna(b['Bsmt Full Bath'].mode()[0]) 
b['Bsmt Half Bath'] = b['Bsmt Half Bath'].fillna(b['Bsmt Half Bath'].mode()[0])

# %%
b.isna().sum()
# Out:
# MS SubClass        0
# Lot Frontage       0
# Lot Area           0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Mas Vnr Area       0
# BsmtFin SF 1       0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# TotRms AbvGrd      0
# Fireplaces         0
# Garage Yr Blt      0
# Garage Cars        0
# Garage Area        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
# 3Ssn Porch         0
# Screen Porch       0
# Pool Area          0
# Misc Val           0
# Mo Sold            0
# Yr Sold            0
# SalePrice          0
# dtype: int64

# %%
b.duplicated().sum()
# Out:
# 2

# %%
df.describe(include = 'all')
# Out:
#              Order           PID  MS SubClass MS Zoning  Lot Frontage  \
# count   2930.00000  2.930000e+03  2930.000000      2930   2440.000000
# unique         NaN           NaN          NaN         7           NaN
# top            NaN           NaN          NaN        RL           NaN
# freq           NaN           NaN          NaN      2273           NaN
# mean    1465.50000  7.144645e+08    57.387372       NaN     69.224590
# std      845.96247  1.887308e+08    42.638025       NaN     23.365335
# min        1.00000  5.263011e+08    20.000000       NaN     21.000000
# 25%      733.25000  5.284770e+08    20.000000       NaN     58.000000
# 50%     1465.50000  5.354536e+08    50.000000       NaN     68.000000
# 75%     2197.75000  9.071811e+08    70.000000       NaN     80.000000
# max     2930.00000  1.007100e+09   190.000000       NaN    313.000000
#
#              Lot Area Street Alley Lot Shape Land Contour      ...        \
# ...

# %%
c = df.drop(columns=df._get_numeric_data().columns)

c.isna().sum()/c.shape[0]*100
# Out:
# MS Zoning          0.000000
# Street             0.000000
# Alley             93.242321
# Lot Shape          0.000000
# Land Contour       0.000000
# Utilities          0.000000
# Lot Config         0.000000
# Land Slope         0.000000
# Neighborhood       0.000000
# Condition 1        0.000000
# Condition 2        0.000000
# Bldg Type          0.000000
# House Style        0.000000
# Roof Style         0.000000
# Roof Matl          0.000000
# Exterior 1st       0.000000
# Exterior 2nd       0.000000
# Mas Vnr Type       0.784983
# Exter Qual         0.000000
# Exter Cond         0.000000
# Foundation         0.000000
# Bsmt Qual          2.730375
# Bsmt Cond          2.730375
# Bsmt Exposure      2.832765
# BsmtFin Type 1     2.730375
# BsmtFin Type 2     2.764505
# Heating            0.000000
# Heating QC         0.000000
# Central Air        0.000000
# Electrical         0.034130
# Kitchen Qual       0.000000
# Functional         0.000000
# Fireplace Qu      48.532423
# ...

# %%
d=c.drop(columns=['Pool QC','Fence','Misc Feature','Alley','Fireplace Qu'])
d.isna().sum()/d.shape[0]*100
# Out:
# MS Zoning         0.000000
# Street            0.000000
# Lot Shape         0.000000
# Land Contour      0.000000
# Utilities         0.000000
# Lot Config        0.000000
# Land Slope        0.000000
# Neighborhood      0.000000
# Condition 1       0.000000
# Condition 2       0.000000
# Bldg Type         0.000000
# House Style       0.000000
# Roof Style        0.000000
# Roof Matl         0.000000
# Exterior 1st      0.000000
# Exterior 2nd      0.000000
# Mas Vnr Type      0.784983
# Exter Qual        0.000000
# Exter Cond        0.000000
# Foundation        0.000000
# Bsmt Qual         2.730375
# Bsmt Cond         2.730375
# Bsmt Exposure     2.832765
# BsmtFin Type 1    2.730375
# BsmtFin Type 2    2.764505
# Heating           0.000000
# Heating QC        0.000000
# Central Air       0.000000
# Electrical        0.034130
# Kitchen Qual      0.000000
# Functional        0.000000
# Garage Type       5.358362
# Garage Finish     5.426621
# Garage Qual       5.426621
# ...

# %%
d['Bsmt Qual'] = d['Bsmt Qual'].fillna('none')
d['Bsmt Cond'] = d['Bsmt Cond'].fillna(d['Bsmt Cond'].mode()[0])
d['Bsmt Exposure'] = d['Bsmt Exposure'].fillna(d['Bsmt Exposure'].mode()[0])
d['BsmtFin Type 1'] = d['BsmtFin Type 1'].fillna(d['BsmtFin Type 1'].mode()[0])
d['BsmtFin Type 2'] = d['BsmtFin Type 2'].fillna(d['BsmtFin Type 2'].mode()[0])
d['Mas Vnr Type'] = d['Mas Vnr Type'].fillna(d['Mas Vnr Type'].mode()[0])
d['Electrical'] = d['Electrical'].fillna(d['Electrical'].mode()[0])
d['Garage Type'] = d['Garage Type'].fillna(d['Garage Type'].mode()[0])
d['Garage Finish'] = d['Garage Finish'].fillna(d['Garage Finish'].mode()[0])     
d['Garage Qual'] = d['Garage Qual'].fillna(d['Garage Qual'].mode()[0])        
d['Garage Cond'] = d['Garage Cond'].fillna(d['Garage Cond'].mode()[0])

# %%
d.isna().sum()
# Out:
# MS Zoning         0
# Street            0
# Lot Shape         0
# Land Contour      0
# Utilities         0
# Lot Config        0
# Land Slope        0
# Neighborhood      0
# Condition 1       0
# Condition 2       0
# Bldg Type         0
# House Style       0
# Roof Style        0
# Roof Matl         0
# Exterior 1st      0
# Exterior 2nd      0
# Mas Vnr Type      0
# Exter Qual        0
# Exter Cond        0
# Foundation        0
# Bsmt Qual         0
# Bsmt Cond         0
# Bsmt Exposure     0
# BsmtFin Type 1    0
# BsmtFin Type 2    0
# Heating           0
# Heating QC        0
# Central Air       0
# Electrical        0
# Kitchen Qual      0
# Functional        0
# Garage Type       0
# Garage Finish     0
# Garage Qual       0
# Garage Cond       0
# Paved Drive       0
# Sale Type         0
# Sale Condition    0
# dtype: int64

# %%
e = pd.concat([b,d],axis=1)
e.head()
# Out:
#    MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0           20         141.0     31770             6             5
# 1           20          80.0     11622             5             6
# 2           20          81.0     14267             6             6
# 3           20          93.0     11160             7             5
# 4           60          74.0     13830             5             5
#
#    Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0        1960            1960         112.0         639.0           0.0
# 1        1961            1961           0.0         468.0         144.0
# 2        1958            1958         108.0         923.0           0.0
# 3        1968            1968           0.0        1065.0           0.0
# 4        1997            1998           0.0         791.0           0.0
#
#         ...        Electrical  Kitchen Qual  Functional  Garage Type  \
# ...

# %%
e.isna().sum()
# Out:
# MS SubClass        0
# Lot Frontage       0
# Lot Area           0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Mas Vnr Area       0
# BsmtFin SF 1       0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# TotRms AbvGrd      0
# Fireplaces         0
# Garage Yr Blt      0
# Garage Cars        0
# Garage Area        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
#                   ..
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# ...

# %%
e.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis

# %%
e['SalePrice'].describe(include='all')
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# we can guess by seeing above values if max greater than 75% then possible outlier

# %%
plt.hist(e['SalePrice'],bins=30)
plt.title("target distribution")
plt.show()

# %%
e['SalePrice'].skew()
# Out:
# 1.7435000757376466

# %%
plt.boxplot(e['SalePrice'])
plt.title('target boxplot')
plt.show()

# %% [markdown]
# log transformation

# %%
e['LogSalePrice'] = np.log1p(e['SalePrice'])
e['LogSalePrice'].skew()
# Out:
# -0.014772659537224314

# %% [markdown]
# 100000
# 200000
# 800000
# range is huge
# but we use y = log(1+y)
# this compress large values
#
# ex
#    1. log(100k) = 11.51
#    2. log(200k) = 12.20
#    3. log(800k) = 13.59
#
# used to handle skewness

# %%
e.shape
# Out:
# (2930, 76)

# %%
e.dtypes.value_counts()
# Out:
# object     38
# int64      26
# float64    12
# dtype: int64

# %%
cat_col = e.drop(columns = e._get_numeric_data().columns)
for col in cat_col:
    print(col,e[col].nunique())
# Out:
# MS Zoning 7
# Street 2
# Lot Shape 4
# Land Contour 4
# Utilities 3
# Lot Config 5
# Land Slope 3
# Neighborhood 28
# Condition 1 9
# Condition 2 8
# Bldg Type 5
# House Style 8
# Roof Style 6
# Roof Matl 8
# Exterior 1st 16
# Exterior 2nd 17
# Mas Vnr Type 5
# Exter Qual 4
# Exter Cond 5
# Foundation 6
# Bsmt Qual 6
# Bsmt Cond 5
# Bsmt Exposure 4
# BsmtFin Type 1 6
# BsmtFin Type 2 6
# Heating 6
# Heating QC 5
# Central Air 2
# Electrical 5
# Kitchen Qual 5
# Functional 8
# Garage Type 6
# Garage Finish 3
# Garage Qual 5
# Garage Cond 5
# Paved Drive 3
# Sale Type 10
# Sale Condition 6

# %% [markdown]
# correlation

# %%
num_e = e._get_numeric_data()
corr = e.corr()
corr
# Out:
#                  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# MS SubClass         1.000000     -0.391497 -0.204613      0.039419
# Lot Frontage       -0.391497      1.000000  0.362758      0.198917
# Lot Area           -0.204613      0.362758  1.000000      0.097188
# Overall Qual        0.039419      0.198917  0.097188      1.000000
# Overall Cond       -0.067349     -0.067140 -0.034759     -0.094812
# Year Built          0.036579      0.114341  0.023258      0.597027
# Year Remod/Add      0.043397      0.086139  0.021682      0.569609
# Mas Vnr Area        0.003634      0.201685  0.125950      0.423089
# BsmtFin SF 1       -0.060019      0.198161  0.191574      0.284091
# BsmtFin SF 2       -0.070847      0.039157  0.083198     -0.041122
# Bsmt Unf SF        -0.130339      0.109586  0.023696      0.270062
# Total Bsmt SF      -0.219374      0.329406  0.253601      0.547157
# 1st Flr SF         -0.247828      0.422305  0.332235      0.477837
# ...

# %%
corr_target = corr['LogSalePrice'].sort_values(ascending=False)
print(corr_target),print()
# Out:
# LogSalePrice       1.000000
# SalePrice          0.946304
# Overall Qual       0.825645
# Gr Liv Area        0.695863
# Garage Cars        0.675276
# Garage Area        0.651123
# Total Bsmt SF      0.624828
# Year Built         0.615485
# 1st Flr SF         0.602629
# Year Remod/Add     0.586153
# Full Bath          0.577335
# Garage Yr Blt      0.540362
# TotRms AbvGrd      0.492580
# Fireplaces         0.488945
# Mas Vnr Area       0.442984
# BsmtFin SF 1       0.410665
# Wood Deck SF       0.333320
# Lot Frontage       0.330226
# Open Porch SF      0.319938
# Half Bath          0.305921
# Bsmt Full Bath     0.275089
# 2nd Flr SF         0.274692
# Lot Area           0.255032
# Bsmt Unf SF        0.193811
# Bedroom AbvGr      0.180503
# Screen Porch       0.110425
# Pool Area          0.054403
# 3Ssn Porch         0.040248
# Mo Sold            0.038960
# BsmtFin SF 2       0.018504
# Misc Val          -0.008718
# Bsmt Half Bath    -0.020893
# Yr Sold           -0.033131
# ...

# %%
corr_matrix = corr
threshold = 0.8
for col in corr_matrix.columns:
    h = corr_matrix.index[(corr_matrix[col].abs() > threshold) & (corr_matrix.index != col)]
    if len(h)>0:
        print(col,"is highly correlated with:",list(h))
# Out:
# Overall Qual is highly correlated with: ['LogSalePrice']
# Total Bsmt SF is highly correlated with: ['1st Flr SF']
# 1st Flr SF is highly correlated with: ['Total Bsmt SF']
# Gr Liv Area is highly correlated with: ['TotRms AbvGrd']
# TotRms AbvGrd is highly correlated with: ['Gr Liv Area']
# Garage Cars is highly correlated with: ['Garage Area']
# Garage Area is highly correlated with: ['Garage Cars']
# SalePrice is highly correlated with: ['LogSalePrice']
# LogSalePrice is highly correlated with: ['Overall Qual', 'SalePrice']

# %%
for cols in num_e.columns:
    print(f"{cols} : {num_e[cols].skew()}")
# Out:
# MS SubClass : 1.357579440916994
# Lot Frontage : 1.670203603402061
# Lot Area : 12.820898171092683
# Overall Qual : 0.19063395602395453
# Overall Cond : 0.5744294770321867
# Year Built : -0.6044622213681589
# Year Remod/Add : -0.4518626526946543
# Mas Vnr Area : 2.6193051302542334
# BsmtFin SF 1 : 1.4165672363063189
# BsmtFin SF 2 : 4.140793742804167
# Bsmt Unf SF : 0.9234030410077413
# Total Bsmt SF : 1.1565322593507308
# 1st Flr SF : 1.4694286403471462
# 2nd Flr SF : 0.8664567507736954
# Low Qual Fin SF : 12.118161563533523
# Gr Liv Area : 1.2741097164955077
# Bsmt Full Bath : 0.6177277112577007
# Bsmt Half Bath : 3.94238925336353
# Full Bath : 0.17195207751092292
# Half Bath : 0.6977130658109041
# Bedroom AbvGr : 0.30569421135922614
# Kitchen AbvGr : 4.313824595352703
# TotRms AbvGrd : 0.7535425619291304
# Fireplaces : 0.739215201197961
# Garage Yr Blt : -0.401195753859053
# Garage Cars : -0.2201675972639356
# Garage Area : 0.24200116201946423
# Wood Deck SF : 1.8426780991633038
# ...

# %%
num_e.dtypes
# Out:
# MS SubClass          int64
# Lot Frontage       float64
# Lot Area             int64
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Mas Vnr Area       float64
# BsmtFin SF 1       float64
# BsmtFin SF 2       float64
# Bsmt Unf SF        float64
# Total Bsmt SF      float64
# 1st Flr SF           int64
# 2nd Flr SF           int64
# Low Qual Fin SF      int64
# Gr Liv Area          int64
# Bsmt Full Bath     float64
# Bsmt Half Bath     float64
# Full Bath            int64
# Half Bath            int64
# Bedroom AbvGr        int64
# Kitchen AbvGr        int64
# TotRms AbvGrd        int64
# Fireplaces           int64
# Garage Yr Blt      float64
# Garage Cars        float64
# Garage Area        float64
# Wood Deck SF         int64
# Open Porch SF        int64
# Enclosed Porch       int64
# 3Ssn Porch           int64
# Screen Porch         int64
# Pool Area            int64
# Misc Val             int64
# ...

# %%
for c in cat_col:
    print("\n",c)
    print(e.groupby(c)['LogSalePrice'].mean().sort_values())
# Out:
#  MS Zoning
# MS Zoning
# A (agr)    10.394407
# C (all)    11.209777
# I (all)    11.252112
# RM         11.692192
# RH         11.785074
# RL         12.086429
# FV         12.269621
# Name: LogSalePrice, dtype: float64
#
#  Street
# Street
# Grvl    11.460924
# Pave    12.023278
# Name: LogSalePrice, dtype: float64
#
#  Lot Shape
# Lot Shape
# Reg    11.920067
# IR1    12.188841
# IR3    12.228761
# IR2    12.283120
# Name: LogSalePrice, dtype: float64
#
#  Land Contour
# Land Contour
# Bnk    11.821649
# Lvl    12.014527
# Low    12.061615
# HLS    12.336494
# Name: LogSalePrice, dtype: float64
#
#  Utilities
# Utilities
# NoSewr    11.307213
# NoSeWa    11.831386
# AllPub    12.021528
# Name: LogSalePrice, dtype: float64
#
#  Lot Config
# Lot Config
# Inside     12.002920
# Corner     12.014082
# FR2        12.018723
# FR3        12.109673
# CulDSac    12.249371
# Name: LogSalePrice, dtype: float64
#
#  Land Slope
# Land Slope
# Gtl    12.016562
# Mod    12.102549
# ...

# %%
print("short break")
# Out:
# short break
